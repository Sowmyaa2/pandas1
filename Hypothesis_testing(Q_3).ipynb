# %% [markdown]
# <a href="https://colab.research.google.com/github/Sowmyaa2/pandas1/blob/main/Hypothesis_testing(Q_3).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
import scipy.stats as stats
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
import scipy
from scipy import stats

# %%
df= pd.read_csv('BuyerRatio.csv')
df
# Out:
#   Observed Values  East  West  North  South
# 0           Males    50   142    131     70
# 1         Females   435  1523   1356    750

# %%
df.head(5)
# Out:
#   Observed Values  East  West  North  South
# 0           Males    50   142    131     70
# 1         Females   435  1523   1356    750

# %%
df.describe()
# Out:
#              East         West        North       South
# count    2.000000     2.000000     2.000000    2.000000
# mean   242.500000   832.500000   743.500000  410.000000
# std    272.236111   976.514465   866.205807  480.832611
# min     50.000000   142.000000   131.000000   70.000000
# 25%    146.250000   487.250000   437.250000  240.000000
# 50%    242.500000   832.500000   743.500000  410.000000
# 75%    338.750000  1177.750000  1049.750000  580.000000
# max    435.000000  1523.000000  1356.000000  750.000000

# %%
df_table=df.iloc[0:,2:10]
df_table
# Out:
#    West  North  South
# 0   142    131     70
# 1  1523   1356    750

# %%
df_table.values
# Out:
# array([[ 142,  131,   70],
#        [1523, 1356,  750]])

# %%
Chisquares_results=scipy.stats.chi2_contingency (df_table)
Chisquares_results
# Out:
# Chi2ContingencyResult(statistic=0.091499885613484, pvalue=0.955280807164431, dof=2, expected_freq=array([[ 143.78021148,  128.4091138 ,   70.81067472],
#        [1521.21978852, 1358.5908862 ,  749.18932528]]))

# %%
no_of_rows=len(df_table.iloc[1:3,0])
no_of_columns=len(df_table.iloc[0,1:6])
degree_of_f=(no_of_rows-1)*(no_of_columns-1)
print('Degree of Freedom=',degree_of_f)
Expected_value=val[3]
Expected_value
# Out:
# Degree of Freedom= 0
# array([[ 143.78021148,  128.4091138 ,   70.81067472],
#        [1521.21978852, 1358.5908862 ,  749.18932528]])

# %%
from scipy.stats import chi2
chi_square=sum([(o-e)**2/e for o,e in zip(df_table.values,Expected_value)])
chi_square_statestic=chi_square[0]+chi_square[1]
chi_square_statestic
critical_value=chi2.ppf(0.95,3)
critical_value
# Out:
# 7.814727903251179

# %%
if chi_square_statestic >= critical_value:
	print('Dependent (reject H0)')
else:
	print('Independent (fail to reject H0)')
# Out:
# Independent (fail to reject H0)

# %%
pvalue=1-chi2.cdf(chi_square_statestic,3)
pvalue
# Out:
# 0.9939783523948621

# %%
if pvalue <= 0.05:
	print('Dependent (reject H0)')
else:
	print('Independent (fail to reject H0)')
# Out:
# Independent (fail to reject H0)

# %%
Chi_square=[['','Test Statistic','p-value'],['Sample Data',Chisquares_results[0],Chisquares_results[1]]]
Chi_square
# Out:
# [['', 'Test Statistic', 'p-value'],
#  ['Sample Data', 0.091499885613484, 0.955280807164431]]
