# %% [markdown]
# <a href="https://colab.research.google.com/github/Sowmyaa2/pandas1/blob/main/Hypothesis_testing(Q_2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import libraries
import pandas as pd
import numpy as np
from scipy import stats
from scipy.stats import norm
import matplotlib.pyplot as plt
import seaborn as sns

# %%
LabTAT=pd.read_csv("LabTAT.csv")
LabTAT
# Out:
#      Laboratory 1  Laboratory 2  Laboratory 3  Laboratory 4
# 0          185.35        165.53        176.70        166.13
# 1          170.49        185.91        198.45        160.79
# 2          192.77        194.92        201.23        185.18
# 3          177.33        183.00        199.61        176.42
# 4          193.41        169.57        204.63        152.60
# ..            ...           ...           ...           ...
# 115        178.49        170.66        193.80        172.68
# 116        176.08        183.98        215.25        177.64
# 117        202.48        174.54        203.99        170.27
# 118        182.40        197.18        194.52        150.87
# 119        182.09        215.17        221.49        162.21
#
# [120 rows x 4 columns]

# %%
LabTAT.describe()
# Out:
#        Laboratory 1  Laboratory 2  Laboratory 3  Laboratory 4
# count    120.000000    120.000000    120.000000     120.00000
# mean     178.361583    178.902917    199.913250     163.68275
# std       13.173594     14.957114     16.539033      15.08508
# min      138.300000    140.550000    159.690000     124.06000
# 25%      170.335000    168.025000    188.232500     154.05000
# 50%      178.530000    178.870000    199.805000     164.42500
# 75%      186.535000    189.112500    211.332500     172.88250
# max      216.390000    217.860000    238.700000     205.18000

# %%
LabTAT.head(10)
# Out:
#    Laboratory 1  Laboratory 2  Laboratory 3  Laboratory 4
# 0        185.35        165.53        176.70        166.13
# 1        170.49        185.91        198.45        160.79
# 2        192.77        194.92        201.23        185.18
# 3        177.33        183.00        199.61        176.42
# 4        193.41        169.57        204.63        152.60
# 5        179.45        197.00        181.51        161.12
# 6        191.37        166.36        214.21        154.02
# 7        166.81        169.60        183.43        163.25
# 8        158.81        175.36        191.60        152.79
# 9        165.88        198.68        208.43        161.98

# %%
LabTAT.tail(10)
# Out:
#      Laboratory 1  Laboratory 2  Laboratory 3  Laboratory 4
# 110        172.05        174.43        211.64        152.31
# 111        181.88        168.20        183.19        191.26
# 112        201.11        195.07        203.05        160.98
# 113        154.21        193.79        197.88        192.23
# 114        145.89        175.16        203.39        139.34
# 115        178.49        170.66        193.80        172.68
# 116        176.08        183.98        215.25        177.64
# 117        202.48        174.54        203.99        170.27
# 118        182.40        197.18        194.52        150.87
# 119        182.09        215.17        221.49        162.21

# %%
import scipy.stats as stats;
p_value=stats.f_oneway(LabTAT.iloc[0:,0],LabTAT.iloc[0:,1],LabTAT.iloc[0:,2],LabTAT.iloc[0:,3])
p_value
# Out:
# F_onewayResult(statistic=118.70421654401437, pvalue=2.1156708949992414e-57)

# %%
plt.hist(LabTAT['Laboratory 1'])
plt.title('Histogram of Laboratory 1')
plt.xlabel('Laboratory 1')
plt.ylabel('Laboratory 2')
plt.show()

# %%
plt.boxplot(LabTAT['Laboratory 1'])
plt.title('Boxplot of Laboratory 1')
plt.xlabel('Laboratory 1')
plt.ylabel('Laboratory 2')
plt.show()

# %%
p_value[1]
# Out:
# 2.1156708949992414e-57
